# %%
from pybrain.tools.shortcuts import buildNetwork 
from pybrain.datasets import SupervisedDataSet
from pybrain.supervised.trainers import BackpropTrainer
import csv
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
# %matplotlib inline

# %%
dia = csv.excel()
df = pd.read_csv("Ncircle.csv")

# %%
 X,Y = df[['X','Y']],df[['T']]

# %%
neigh = KNeighborsClassifier(n_neighbors=1)
neigh.fit(X, Y) 

pred=(neigh.predict(X))
# Out:
# C:\Anaconda\lib\site-packages\IPython\kernel\__main__.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   from IPython.kernel.zmq import kernelapp as app

# %%
from sklearn.metrics import accuracy_score
accuracy_score(Y,pred)
# Out:
# 1.0

# %%
from sklearn.metrics import confusion_matrix
import numpy as np
confusion_matrix(np.asarray(Y),pred)
# Out:
# array([[716,   0],
#        [  0, 284]])

# %%
import pylab
plt.scatter(df[['X']],df[['Y']],color='red')
axes = pylab.axes()
circle1 = pylab.Circle((0,0), radius=1, alpha=.5)
circle2 = pylab.Circle((4,3), radius=1.25, alpha=.5)
circle3 = pylab.Circle((1,2), radius=1.5, alpha=.5)
circle4 = pylab.Circle((-2,-2), radius=1.75, alpha=.5)
circle5 = pylab.Circle((-2,-3), radius=2, alpha=.5)


axes.add_patch(circle1)
axes.add_patch(circle2)
axes.add_patch(circle3)
axes.add_patch(circle4)
axes.add_patch(circle5)

pylab.axis('scaled')
pylab.show()
